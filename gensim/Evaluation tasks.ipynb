# %% [markdown]
# # Synthetic "chord reasoning" questionsets

# %% [markdown]
# ## Analogy
#
# Generate all pairs
#
# ```
# C7:D7::F:G
# C7:A7::F:E
# ```

# %%
import music21
import functools

@functools.lru_cache(maxsize=None)
def c_to_strep(c):
    rep = ""
    for i in range(12):
        if i in c.pitchClasses:
            rep += "1"
        else:
            rep += "0"
    return rep

@functools.lru_cache(maxsize=None)
def transpose_to_all(c):
    out = []
    old = c
    for i in range(12):
        new = old.transpose(7)
        out.append(new)
        old = new
    return out

@functools.lru_cache(maxsize=None)
def strep_to_c(strep):
    pcs = []
    for i, v in enumerate(strep):
        if v == '1':
            pcs.append(i)
    return music21.chord.Chord(pcs)

# %%
dominant_of = music21.chord.Chord('G B D F')
tonic = music21.chord.Chord('C E G')

# %%
all_tonics = transpose_to_all(tonic)
all_dominants = transpose_to_all(dominant_of)

# %%
def strep_to_human(strep):
    return strep_to_c(strep).root().name + " " + strep_to_c(strep).commonName

# %%
with open('analogies_D1D2T1T2.eval', 'w') as f:
    for i in range(len(all_dominants)):
        for j in range(len(all_tonics)):
            a = c_to_strep(all_dominants[i])
            b = c_to_strep(all_dominants[j])
            c = c_to_strep(all_tonics[i])
            d = c_to_strep(all_tonics[j])
            if (a,b) != (c,d) and a != b and c != d:
                to_write =[a, b, c, d]
                f.write("\t".join(to_write)+'\n')
                print([strep_to_human(s) for s in to_write])
# Out:
# ['D dominant seventh chord', 'A dominant seventh chord', 'G major triad', 'D major triad']
# ['D dominant seventh chord', 'E dominant seventh chord', 'G major triad', 'A major triad']
# ['D dominant seventh chord', 'F# dominant seventh chord', 'G major triad', 'E major triad']
# ['D dominant seventh chord', 'F# dominant seventh chord', 'G major triad', 'C- major triad']
# ['D dominant seventh chord', 'C# dominant seventh chord', 'G major triad', 'F# major triad']
# ['D dominant seventh chord', 'A- dominant seventh chord', 'G major triad', 'C# major triad']
# ['D dominant seventh chord', 'D# dominant seventh chord', 'G major triad', 'A- major triad']
# ['D dominant seventh chord', 'B- dominant seventh chord', 'G major triad', 'E- major triad']
# ['D dominant seventh chord', 'F dominant seventh chord', 'G major triad', 'B- major triad']
# ['D dominant seventh chord', 'C dominant seventh chord', 'G major triad', 'F major triad']
# ['D dominant seventh chord', 'G dominant seventh chord', 'G major triad', 'C major triad']
# ['A dominant seventh chord', 'D dominant seventh chord', 'D major triad', 'G major triad']
# ['A dominant seventh chord', 'E dominant seventh chord', 'D major triad', 'A major triad']
# ['A dominant seventh chord', 'F# dominant seventh chord', 'D major triad', 'E major triad']
# ['A dominant seventh chord', 'F# dominant seventh chord', 'D major triad', 'C- major triad']
# ['A dominant seventh chord', 'C# dominant seventh chord', 'D major triad', 'F# major triad']
# ['A dominant seventh chord', 'A- dominant seventh chord', 'D major triad', 'C# major triad']
# ['A dominant seventh chord', 'D# dominant seventh chord', 'D major triad', 'A- major triad']
# ['A dominant seventh chord', 'B- dominant seventh chord', 'D major triad', 'E- major triad']
# ['A dominant seventh chord', 'F dominant seventh chord', 'D major triad', 'B- major triad']
# ['A dominant seventh chord', 'C dominant seventh chord', 'D major triad', 'F major triad']
# ['A dominant seventh chord', 'G dominant seventh chord', 'D major triad', 'C major triad']
# ['E dominant seventh chord', 'D dominant seventh chord', 'A major triad', 'G major triad']
# ['E dominant seventh chord', 'A dominant seventh chord', 'A major triad', 'D major triad']
# ['E dominant seventh chord', 'F# dominant seventh chord', 'A major triad', 'E major triad']
# ['E dominant seventh chord', 'F# dominant seventh chord', 'A major triad', 'C- major triad']
# ['E dominant seventh chord', 'C# dominant seventh chord', 'A major triad', 'F# major triad']
# ['E dominant seventh chord', 'A- dominant seventh chord', 'A major triad', 'C# major triad']
# ['E dominant seventh chord', 'D# dominant seventh chord', 'A major triad', 'A- major triad']
# ['E dominant seventh chord', 'B- dominant seventh chord', 'A major triad', 'E- major triad']
# ['E dominant seventh chord', 'F dominant seventh chord', 'A major triad', 'B- major triad']
# ['E dominant seventh chord', 'C dominant seventh chord', 'A major triad', 'F major triad']
# ['E dominant seventh chord', 'G dominant seventh chord', 'A major triad', 'C major triad']
# ['F# dominant seventh chord', 'D dominant seventh chord', 'E major triad', 'G major triad']
# ['F# dominant seventh chord', 'A dominant seventh chord', 'E major triad', 'D major triad']
# ['F# dominant seventh chord', 'E dominant seventh chord', 'E major triad', 'A major triad']
# ['F# dominant seventh chord', 'F# dominant seventh chord', 'E major triad', 'C- major triad']
# ['F# dominant seventh chord', 'C# dominant seventh chord', 'E major triad', 'F# major triad']
# ['F# dominant seventh chord', 'A- dominant seventh chord', 'E major triad', 'C# major triad']
# ['F# dominant seventh chord', 'D# dominant seventh chord', 'E major triad', 'A- major triad']
# ['F# dominant seventh chord', 'B- dominant seventh chord', 'E major triad', 'E- major triad']
# ['F# dominant seventh chord', 'F dominant seventh chord', 'E major triad', 'B- major triad']
# ['F# dominant seventh chord', 'C dominant seventh chord', 'E major triad', 'F major triad']
# ['F# dominant seventh chord', 'G dominant seventh chord', 'E major triad', 'C major triad']
# ['F# dominant seventh chord', 'D dominant seventh chord', 'C- major triad', 'G major triad']
# ['F# dominant seventh chord', 'A dominant seventh chord', 'C- major triad', 'D major triad']
# ['F# dominant seventh chord', 'E dominant seventh chord', 'C- major triad', 'A major triad']
# ['F# dominant seventh chord', 'F# dominant seventh chord', 'C- major triad', 'E major triad']
# ['F# dominant seventh chord', 'C# dominant seventh chord', 'C- major triad', 'F# major triad']
# ['F# dominant seventh chord', 'A- dominant seventh chord', 'C- major triad', 'C# major triad']
# ['F# dominant seventh chord', 'D# dominant seventh chord', 'C- major triad', 'A- major triad']
# ['F# dominant seventh chord', 'B- dominant seventh chord', 'C- major triad', 'E- major triad']
# ['F# dominant seventh chord', 'F dominant seventh chord', 'C- major triad', 'B- major triad']
# ['F# dominant seventh chord', 'C dominant seventh chord', 'C- major triad', 'F major triad']
# ['F# dominant seventh chord', 'G dominant seventh chord', 'C- major triad', 'C major triad']
# ['C# dominant seventh chord', 'D dominant seventh chord', 'F# major triad', 'G major triad']
# ['C# dominant seventh chord', 'A dominant seventh chord', 'F# major triad', 'D major triad']
# ['C# dominant seventh chord', 'E dominant seventh chord', 'F# major triad', 'A major triad']
# ['C# dominant seventh chord', 'F# dominant seventh chord', 'F# major triad', 'E major triad']
# ['C# dominant seventh chord', 'F# dominant seventh chord', 'F# major triad', 'C- major triad']
# ['C# dominant seventh chord', 'A- dominant seventh chord', 'F# major triad', 'C# major triad']
# ['C# dominant seventh chord', 'D# dominant seventh chord', 'F# major triad', 'A- major triad']
# ['C# dominant seventh chord', 'B- dominant seventh chord', 'F# major triad', 'E- major triad']
# ['C# dominant seventh chord', 'F dominant seventh chord', 'F# major triad', 'B- major triad']
# ['C# dominant seventh chord', 'C dominant seventh chord', 'F# major triad', 'F major triad']
# ['C# dominant seventh chord', 'G dominant seventh chord', 'F# major triad', 'C major triad']
# ['A- dominant seventh chord', 'D dominant seventh chord', 'C# major triad', 'G major triad']
# ['A- dominant seventh chord', 'A dominant seventh chord', 'C# major triad', 'D major triad']
# ['A- dominant seventh chord', 'E dominant seventh chord', 'C# major triad', 'A major triad']
# ['A- dominant seventh chord', 'F# dominant seventh chord', 'C# major triad', 'E major triad']
# ['A- dominant seventh chord', 'F# dominant seventh chord', 'C# major triad', 'C- major triad']
# ['A- dominant seventh chord', 'C# dominant seventh chord', 'C# major triad', 'F# major triad']
# ['A- dominant seventh chord', 'D# dominant seventh chord', 'C# major triad', 'A- major triad']
# ['A- dominant seventh chord', 'B- dominant seventh chord', 'C# major triad', 'E- major triad']
# ['A- dominant seventh chord', 'F dominant seventh chord', 'C# major triad', 'B- major triad']
# ['A- dominant seventh chord', 'C dominant seventh chord', 'C# major triad', 'F major triad']
# ['A- dominant seventh chord', 'G dominant seventh chord', 'C# major triad', 'C major triad']
# ['D# dominant seventh chord', 'D dominant seventh chord', 'A- major triad', 'G major triad']
# ['D# dominant seventh chord', 'A dominant seventh chord', 'A- major triad', 'D major triad']
# ['D# dominant seventh chord', 'E dominant seventh chord', 'A- major triad', 'A major triad']
# ['D# dominant seventh chord', 'F# dominant seventh chord', 'A- major triad', 'E major triad']
# ['D# dominant seventh chord', 'F# dominant seventh chord', 'A- major triad', 'C- major triad']
# ['D# dominant seventh chord', 'C# dominant seventh chord', 'A- major triad', 'F# major triad']
# ['D# dominant seventh chord', 'A- dominant seventh chord', 'A- major triad', 'C# major triad']
# ['D# dominant seventh chord', 'B- dominant seventh chord', 'A- major triad', 'E- major triad']
# ['D# dominant seventh chord', 'F dominant seventh chord', 'A- major triad', 'B- major triad']
# ['D# dominant seventh chord', 'C dominant seventh chord', 'A- major triad', 'F major triad']
# ['D# dominant seventh chord', 'G dominant seventh chord', 'A- major triad', 'C major triad']
# ['B- dominant seventh chord', 'D dominant seventh chord', 'E- major triad', 'G major triad']
# ['B- dominant seventh chord', 'A dominant seventh chord', 'E- major triad', 'D major triad']
# ['B- dominant seventh chord', 'E dominant seventh chord', 'E- major triad', 'A major triad']
# ['B- dominant seventh chord', 'F# dominant seventh chord', 'E- major triad', 'E major triad']
# ['B- dominant seventh chord', 'F# dominant seventh chord', 'E- major triad', 'C- major triad']
# ['B- dominant seventh chord', 'C# dominant seventh chord', 'E- major triad', 'F# major triad']
# ['B- dominant seventh chord', 'A- dominant seventh chord', 'E- major triad', 'C# major triad']
# ['B- dominant seventh chord', 'D# dominant seventh chord', 'E- major triad', 'A- major triad']
# ['B- dominant seventh chord', 'F dominant seventh chord', 'E- major triad', 'B- major triad']
# ['B- dominant seventh chord', 'C dominant seventh chord', 'E- major triad', 'F major triad']
# ['B- dominant seventh chord', 'G dominant seventh chord', 'E- major triad', 'C major triad']
# ['F dominant seventh chord', 'D dominant seventh chord', 'B- major triad', 'G major triad']
# ['F dominant seventh chord', 'A dominant seventh chord', 'B- major triad', 'D major triad']
# ['F dominant seventh chord', 'E dominant seventh chord', 'B- major triad', 'A major triad']
# ['F dominant seventh chord', 'F# dominant seventh chord', 'B- major triad', 'E major triad']
# ['F dominant seventh chord', 'F# dominant seventh chord', 'B- major triad', 'C- major triad']
# ['F dominant seventh chord', 'C# dominant seventh chord', 'B- major triad', 'F# major triad']
# ['F dominant seventh chord', 'A- dominant seventh chord', 'B- major triad', 'C# major triad']
# ['F dominant seventh chord', 'D# dominant seventh chord', 'B- major triad', 'A- major triad']
# ['F dominant seventh chord', 'B- dominant seventh chord', 'B- major triad', 'E- major triad']
# ['F dominant seventh chord', 'C dominant seventh chord', 'B- major triad', 'F major triad']
# ['F dominant seventh chord', 'G dominant seventh chord', 'B- major triad', 'C major triad']
# ['C dominant seventh chord', 'D dominant seventh chord', 'F major triad', 'G major triad']
# ['C dominant seventh chord', 'A dominant seventh chord', 'F major triad', 'D major triad']
# ['C dominant seventh chord', 'E dominant seventh chord', 'F major triad', 'A major triad']
# ['C dominant seventh chord', 'F# dominant seventh chord', 'F major triad', 'E major triad']
# ['C dominant seventh chord', 'F# dominant seventh chord', 'F major triad', 'C- major triad']
# ['C dominant seventh chord', 'C# dominant seventh chord', 'F major triad', 'F# major triad']
# ['C dominant seventh chord', 'A- dominant seventh chord', 'F major triad', 'C# major triad']
# ['C dominant seventh chord', 'D# dominant seventh chord', 'F major triad', 'A- major triad']
# ['C dominant seventh chord', 'B- dominant seventh chord', 'F major triad', 'E- major triad']
# ['C dominant seventh chord', 'F dominant seventh chord', 'F major triad', 'B- major triad']
# ['C dominant seventh chord', 'G dominant seventh chord', 'F major triad', 'C major triad']
# ['G dominant seventh chord', 'D dominant seventh chord', 'C major triad', 'G major triad']
# ['G dominant seventh chord', 'A dominant seventh chord', 'C major triad', 'D major triad']
# ['G dominant seventh chord', 'E dominant seventh chord', 'C major triad', 'A major triad']
# ['G dominant seventh chord', 'F# dominant seventh chord', 'C major triad', 'E major triad']
# ['G dominant seventh chord', 'F# dominant seventh chord', 'C major triad', 'C- major triad']
# ['G dominant seventh chord', 'C# dominant seventh chord', 'C major triad', 'F# major triad']
# ['G dominant seventh chord', 'A- dominant seventh chord', 'C major triad', 'C# major triad']
# ['G dominant seventh chord', 'D# dominant seventh chord', 'C major triad', 'A- major triad']
# ['G dominant seventh chord', 'B- dominant seventh chord', 'C major triad', 'E- major triad']
# ['G dominant seventh chord', 'F dominant seventh chord', 'C major triad', 'B- major triad']
# ['G dominant seventh chord', 'C dominant seventh chord', 'C major triad', 'F major triad']

# %%
with open('analogies_D1T1D2T2.eval', 'w') as f:
    for i in range(len(all_dominants)):
        for j in range(len(all_tonics)):
            a = c_to_strep(all_dominants[i])
            c = c_to_strep(all_dominants[j])
            b = c_to_strep(all_tonics[i])
            d = c_to_strep(all_tonics[j])
            if (a,b) != (c,d) and a != b and c != d:
                to_write =[a, b, c, d]
                f.write("\t".join(to_write)+'\n')
                print([strep_to_human(s) for s in to_write])
# Out:
# ['D dominant seventh chord', 'G major triad', 'A dominant seventh chord', 'D major triad']
# ['D dominant seventh chord', 'G major triad', 'E dominant seventh chord', 'A major triad']
# ['D dominant seventh chord', 'G major triad', 'F# dominant seventh chord', 'E major triad']
# ['D dominant seventh chord', 'G major triad', 'F# dominant seventh chord', 'C- major triad']
# ['D dominant seventh chord', 'G major triad', 'C# dominant seventh chord', 'F# major triad']
# ['D dominant seventh chord', 'G major triad', 'A- dominant seventh chord', 'C# major triad']
# ['D dominant seventh chord', 'G major triad', 'D# dominant seventh chord', 'A- major triad']
# ['D dominant seventh chord', 'G major triad', 'B- dominant seventh chord', 'E- major triad']
# ['D dominant seventh chord', 'G major triad', 'F dominant seventh chord', 'B- major triad']
# ['D dominant seventh chord', 'G major triad', 'C dominant seventh chord', 'F major triad']
# ['D dominant seventh chord', 'G major triad', 'G dominant seventh chord', 'C major triad']
# ['A dominant seventh chord', 'D major triad', 'D dominant seventh chord', 'G major triad']
# ['A dominant seventh chord', 'D major triad', 'E dominant seventh chord', 'A major triad']
# ['A dominant seventh chord', 'D major triad', 'F# dominant seventh chord', 'E major triad']
# ['A dominant seventh chord', 'D major triad', 'F# dominant seventh chord', 'C- major triad']
# ['A dominant seventh chord', 'D major triad', 'C# dominant seventh chord', 'F# major triad']
# ['A dominant seventh chord', 'D major triad', 'A- dominant seventh chord', 'C# major triad']
# ['A dominant seventh chord', 'D major triad', 'D# dominant seventh chord', 'A- major triad']
# ['A dominant seventh chord', 'D major triad', 'B- dominant seventh chord', 'E- major triad']
# ['A dominant seventh chord', 'D major triad', 'F dominant seventh chord', 'B- major triad']
# ['A dominant seventh chord', 'D major triad', 'C dominant seventh chord', 'F major triad']
# ['A dominant seventh chord', 'D major triad', 'G dominant seventh chord', 'C major triad']
# ['E dominant seventh chord', 'A major triad', 'D dominant seventh chord', 'G major triad']
# ['E dominant seventh chord', 'A major triad', 'A dominant seventh chord', 'D major triad']
# ['E dominant seventh chord', 'A major triad', 'F# dominant seventh chord', 'E major triad']
# ['E dominant seventh chord', 'A major triad', 'F# dominant seventh chord', 'C- major triad']
# ['E dominant seventh chord', 'A major triad', 'C# dominant seventh chord', 'F# major triad']
# ['E dominant seventh chord', 'A major triad', 'A- dominant seventh chord', 'C# major triad']
# ['E dominant seventh chord', 'A major triad', 'D# dominant seventh chord', 'A- major triad']
# ['E dominant seventh chord', 'A major triad', 'B- dominant seventh chord', 'E- major triad']
# ['E dominant seventh chord', 'A major triad', 'F dominant seventh chord', 'B- major triad']
# ['E dominant seventh chord', 'A major triad', 'C dominant seventh chord', 'F major triad']
# ['E dominant seventh chord', 'A major triad', 'G dominant seventh chord', 'C major triad']
# ['F# dominant seventh chord', 'E major triad', 'D dominant seventh chord', 'G major triad']
# ['F# dominant seventh chord', 'E major triad', 'A dominant seventh chord', 'D major triad']
# ['F# dominant seventh chord', 'E major triad', 'E dominant seventh chord', 'A major triad']
# ['F# dominant seventh chord', 'E major triad', 'F# dominant seventh chord', 'C- major triad']
# ['F# dominant seventh chord', 'E major triad', 'C# dominant seventh chord', 'F# major triad']
# ['F# dominant seventh chord', 'E major triad', 'A- dominant seventh chord', 'C# major triad']
# ['F# dominant seventh chord', 'E major triad', 'D# dominant seventh chord', 'A- major triad']
# ['F# dominant seventh chord', 'E major triad', 'B- dominant seventh chord', 'E- major triad']
# ['F# dominant seventh chord', 'E major triad', 'F dominant seventh chord', 'B- major triad']
# ['F# dominant seventh chord', 'E major triad', 'C dominant seventh chord', 'F major triad']
# ['F# dominant seventh chord', 'E major triad', 'G dominant seventh chord', 'C major triad']
# ['F# dominant seventh chord', 'C- major triad', 'D dominant seventh chord', 'G major triad']
# ['F# dominant seventh chord', 'C- major triad', 'A dominant seventh chord', 'D major triad']
# ['F# dominant seventh chord', 'C- major triad', 'E dominant seventh chord', 'A major triad']
# ['F# dominant seventh chord', 'C- major triad', 'F# dominant seventh chord', 'E major triad']
# ['F# dominant seventh chord', 'C- major triad', 'C# dominant seventh chord', 'F# major triad']
# ['F# dominant seventh chord', 'C- major triad', 'A- dominant seventh chord', 'C# major triad']
# ['F# dominant seventh chord', 'C- major triad', 'D# dominant seventh chord', 'A- major triad']
# ['F# dominant seventh chord', 'C- major triad', 'B- dominant seventh chord', 'E- major triad']
# ['F# dominant seventh chord', 'C- major triad', 'F dominant seventh chord', 'B- major triad']
# ['F# dominant seventh chord', 'C- major triad', 'C dominant seventh chord', 'F major triad']
# ['F# dominant seventh chord', 'C- major triad', 'G dominant seventh chord', 'C major triad']
# ['C# dominant seventh chord', 'F# major triad', 'D dominant seventh chord', 'G major triad']
# ['C# dominant seventh chord', 'F# major triad', 'A dominant seventh chord', 'D major triad']
# ['C# dominant seventh chord', 'F# major triad', 'E dominant seventh chord', 'A major triad']
# ['C# dominant seventh chord', 'F# major triad', 'F# dominant seventh chord', 'E major triad']
# ['C# dominant seventh chord', 'F# major triad', 'F# dominant seventh chord', 'C- major triad']
# ['C# dominant seventh chord', 'F# major triad', 'A- dominant seventh chord', 'C# major triad']
# ['C# dominant seventh chord', 'F# major triad', 'D# dominant seventh chord', 'A- major triad']
# ['C# dominant seventh chord', 'F# major triad', 'B- dominant seventh chord', 'E- major triad']
# ['C# dominant seventh chord', 'F# major triad', 'F dominant seventh chord', 'B- major triad']
# ['C# dominant seventh chord', 'F# major triad', 'C dominant seventh chord', 'F major triad']
# ['C# dominant seventh chord', 'F# major triad', 'G dominant seventh chord', 'C major triad']
# ['A- dominant seventh chord', 'C# major triad', 'D dominant seventh chord', 'G major triad']
# ['A- dominant seventh chord', 'C# major triad', 'A dominant seventh chord', 'D major triad']
# ['A- dominant seventh chord', 'C# major triad', 'E dominant seventh chord', 'A major triad']
# ['A- dominant seventh chord', 'C# major triad', 'F# dominant seventh chord', 'E major triad']
# ['A- dominant seventh chord', 'C# major triad', 'F# dominant seventh chord', 'C- major triad']
# ['A- dominant seventh chord', 'C# major triad', 'C# dominant seventh chord', 'F# major triad']
# ['A- dominant seventh chord', 'C# major triad', 'D# dominant seventh chord', 'A- major triad']
# ['A- dominant seventh chord', 'C# major triad', 'B- dominant seventh chord', 'E- major triad']
# ['A- dominant seventh chord', 'C# major triad', 'F dominant seventh chord', 'B- major triad']
# ['A- dominant seventh chord', 'C# major triad', 'C dominant seventh chord', 'F major triad']
# ['A- dominant seventh chord', 'C# major triad', 'G dominant seventh chord', 'C major triad']
# ['D# dominant seventh chord', 'A- major triad', 'D dominant seventh chord', 'G major triad']
# ['D# dominant seventh chord', 'A- major triad', 'A dominant seventh chord', 'D major triad']
# ['D# dominant seventh chord', 'A- major triad', 'E dominant seventh chord', 'A major triad']
# ['D# dominant seventh chord', 'A- major triad', 'F# dominant seventh chord', 'E major triad']
# ['D# dominant seventh chord', 'A- major triad', 'F# dominant seventh chord', 'C- major triad']
# ['D# dominant seventh chord', 'A- major triad', 'C# dominant seventh chord', 'F# major triad']
# ['D# dominant seventh chord', 'A- major triad', 'A- dominant seventh chord', 'C# major triad']
# ['D# dominant seventh chord', 'A- major triad', 'B- dominant seventh chord', 'E- major triad']
# ['D# dominant seventh chord', 'A- major triad', 'F dominant seventh chord', 'B- major triad']
# ['D# dominant seventh chord', 'A- major triad', 'C dominant seventh chord', 'F major triad']
# ['D# dominant seventh chord', 'A- major triad', 'G dominant seventh chord', 'C major triad']
# ['B- dominant seventh chord', 'E- major triad', 'D dominant seventh chord', 'G major triad']
# ['B- dominant seventh chord', 'E- major triad', 'A dominant seventh chord', 'D major triad']
# ['B- dominant seventh chord', 'E- major triad', 'E dominant seventh chord', 'A major triad']
# ['B- dominant seventh chord', 'E- major triad', 'F# dominant seventh chord', 'E major triad']
# ['B- dominant seventh chord', 'E- major triad', 'F# dominant seventh chord', 'C- major triad']
# ['B- dominant seventh chord', 'E- major triad', 'C# dominant seventh chord', 'F# major triad']
# ['B- dominant seventh chord', 'E- major triad', 'A- dominant seventh chord', 'C# major triad']
# ['B- dominant seventh chord', 'E- major triad', 'D# dominant seventh chord', 'A- major triad']
# ['B- dominant seventh chord', 'E- major triad', 'F dominant seventh chord', 'B- major triad']
# ['B- dominant seventh chord', 'E- major triad', 'C dominant seventh chord', 'F major triad']
# ['B- dominant seventh chord', 'E- major triad', 'G dominant seventh chord', 'C major triad']
# ['F dominant seventh chord', 'B- major triad', 'D dominant seventh chord', 'G major triad']
# ['F dominant seventh chord', 'B- major triad', 'A dominant seventh chord', 'D major triad']
# ['F dominant seventh chord', 'B- major triad', 'E dominant seventh chord', 'A major triad']
# ['F dominant seventh chord', 'B- major triad', 'F# dominant seventh chord', 'E major triad']
# ['F dominant seventh chord', 'B- major triad', 'F# dominant seventh chord', 'C- major triad']
# ['F dominant seventh chord', 'B- major triad', 'C# dominant seventh chord', 'F# major triad']
# ['F dominant seventh chord', 'B- major triad', 'A- dominant seventh chord', 'C# major triad']
# ['F dominant seventh chord', 'B- major triad', 'D# dominant seventh chord', 'A- major triad']
# ['F dominant seventh chord', 'B- major triad', 'B- dominant seventh chord', 'E- major triad']
# ['F dominant seventh chord', 'B- major triad', 'C dominant seventh chord', 'F major triad']
# ['F dominant seventh chord', 'B- major triad', 'G dominant seventh chord', 'C major triad']
# ['C dominant seventh chord', 'F major triad', 'D dominant seventh chord', 'G major triad']
# ['C dominant seventh chord', 'F major triad', 'A dominant seventh chord', 'D major triad']
# ['C dominant seventh chord', 'F major triad', 'E dominant seventh chord', 'A major triad']
# ['C dominant seventh chord', 'F major triad', 'F# dominant seventh chord', 'E major triad']
# ['C dominant seventh chord', 'F major triad', 'F# dominant seventh chord', 'C- major triad']
# ['C dominant seventh chord', 'F major triad', 'C# dominant seventh chord', 'F# major triad']
# ['C dominant seventh chord', 'F major triad', 'A- dominant seventh chord', 'C# major triad']
# ['C dominant seventh chord', 'F major triad', 'D# dominant seventh chord', 'A- major triad']
# ['C dominant seventh chord', 'F major triad', 'B- dominant seventh chord', 'E- major triad']
# ['C dominant seventh chord', 'F major triad', 'F dominant seventh chord', 'B- major triad']
# ['C dominant seventh chord', 'F major triad', 'G dominant seventh chord', 'C major triad']
# ['G dominant seventh chord', 'C major triad', 'D dominant seventh chord', 'G major triad']
# ['G dominant seventh chord', 'C major triad', 'A dominant seventh chord', 'D major triad']
# ['G dominant seventh chord', 'C major triad', 'E dominant seventh chord', 'A major triad']
# ['G dominant seventh chord', 'C major triad', 'F# dominant seventh chord', 'E major triad']
# ['G dominant seventh chord', 'C major triad', 'F# dominant seventh chord', 'C- major triad']
# ['G dominant seventh chord', 'C major triad', 'C# dominant seventh chord', 'F# major triad']
# ['G dominant seventh chord', 'C major triad', 'A- dominant seventh chord', 'C# major triad']
# ['G dominant seventh chord', 'C major triad', 'D# dominant seventh chord', 'A- major triad']
# ['G dominant seventh chord', 'C major triad', 'B- dominant seventh chord', 'E- major triad']
# ['G dominant seventh chord', 'C major triad', 'F dominant seventh chord', 'B- major triad']
# ['G dominant seventh chord', 'C major triad', 'C dominant seventh chord', 'F major triad']
